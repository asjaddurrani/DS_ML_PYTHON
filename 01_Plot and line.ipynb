# %%
#import libraries

import seaborn as sns
import matplotlib.pyplot as plt

#Load dataset
phool=sns.load_dataset("iris")
phool
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#draw a line plot
sns.lineplot(x="sepal_length",y="sepal_width",data=phool)
plt.title("Phool Graph")
plt.xlim(1)     # x-axis
plt.ylim(1)     # y-axis
sns.set_style("dark")   #dark or light color
sns.set_style(style=None,rc=None)  # dark or light color
plt.show()

# %% [markdown]
# ### size of figure

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#Load dataset
phool=sns.load_dataset("iris")

#change figure
plt.figure(figsize=(5,5))

#draw a line plot
sns.lineplot(x="sepal_length",y="sepal_width",data=phool)
plt.title("Phool Graph")
plt.xlim(1)     # x-axis
plt.ylim(1)     # y-axis
plt.show()

# %% [markdown]
# ### Bar Plot

# %%
#import libraries

import seaborn as sns
import matplotlib.pyplot as plt

#Load dataset
phool=sns.load_dataset("iris")
phool

#draw a line plot
sns.barplot(x="species",y="sepal_width",data=phool)
plt.title("Phool Graph")
plt.show()

# %%
#import libraries

import seaborn as sns
import matplotlib.pyplot as plt

#Load dataset
ship=sns.load_dataset("titanic")
ship
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#draw a line plot
sns.barplot(x="sex",y="age",hue="who",data=ship)
plt.title("Phool Graph")
plt.show()

# %% [markdown]
# ### change order,color and error bars

# %%
#draw a line plot
sns.barplot(x="sex",y="age",hue="who",data=ship,order=["female","male"],color="black",ci=None,
           palette='pastel')
plt.title("Phool Graph")
plt.show()

# %%
### use numpy library for estimator

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

#Load dataset
ship=sns.load_dataset("titanic")
ship

#draw a line plot
sns.barplot(x="sex",y="age",hue="who",data=ship,estimator=np.mean,saturation=0.5)
plt.title("Phool Graph")
plt.show()
